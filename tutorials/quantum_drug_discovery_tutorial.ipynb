# %% [markdown]
# # 🧬 Quantum Drug Discovery Tutorial
#
# ## Interactive Guide to Quantum Chemistry & Drug Binding Calculations
#
# Welcome to this comprehensive tutorial on using quantum computing for drug discovery! This notebook will guide you through:
#
# 1. **Molecular Structure Creation** - Build molecules from atoms
# 2. **Quantum Chemistry Fundamentals** - Understand Hamiltonians and basis sets
# 3. **Variational Quantum Eigensolver (VQE)** - Compute ground state energies
# 4. **Binding Energy Calculations** - Predict drug-target interactions
# 5. **Visualization & Analysis** - Interpret results
#
# ### Prerequisites
# - Basic Python programming
# - Familiarity with quantum mechanics concepts (helpful but not required)
# - Interest in computational chemistry and drug discovery
#
# ### Let's Begin! 🚀

# %%
# Import required libraries
import sys
import os

# Add src directory to path
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), 'src'))

import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown, HTML

# Configure matplotlib
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

print("✓ Libraries imported successfully!")
print(f"   NumPy version: {np.__version__}")
print(f"   Python version: {sys.version.split()[0]}")

# %% [markdown]
# ## Part 1: Building Molecular Structures 🧱
#
# In quantum chemistry, we represent molecules as collections of atoms in 3D space. Each atom has:
# - A **symbol** (H, C, N, O, etc.)
# - A **position** in 3D space (x, y, z coordinates in Ångströms)
#
# Let's start by creating some simple molecules!
